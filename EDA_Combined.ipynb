# %% [markdown]
# # Exploratory Data Analysis on Austin Animal Center Together

# %% [markdown]
# ## Table of Contents:
#
#    * [General Information](#general-information)
#    <br/><br/>
#    * [Aged Animals](#aged-animals)
#    <br/><br/>
#    * [Animals Returned](#animals-returned)
#    <br/><br/>
#    * [Location & Time](#location+time)
#    <br/><br/>
#
#     ethunasia 이유로 intake한 동물들이 ethunasia/died로 outcome 되었는 지
#     intake에서 returned한 동물들이 outcome type이 무엇이었는 지

# %%
import pandas as pd

# %%
intakes = pd.read_csv('Cleaned_Intakes.csv',index_col=0)
outcomes = pd.read_csv('Cleaned_Outcomes.csv',index_col=0)

# %%
print("total intakes cases: " + str(intakes.shape[0]))
print("total number of animals: " + str(intakes['Animal ID'].nunique()))
print("number of cases that is not first case of each animal: " + str(intakes.shape[0] - intakes['Animal ID'].nunique()))
# Out:
# total intakes cases: 124120
# total number of animals: 110926
# number of cases that is not first case of each animal: 13194

# %%
print("total outcomes cases: " + str(outcomes.shape[0]))
print("total number of animals: " + str(outcomes['Animal ID'].nunique()))
print("number of cases that is not first case of each animal: " + str(outcomes.shape[0] - outcomes['Animal ID'].nunique()))
# Out:
# total outcomes cases: 124491
# total number of animals: 111309
# number of cases that is not first case of each animal: 13182

# %% [markdown]
#  ## Merge intakes and outcomes
#    *Both intakes and outcomes datasets contain duplicate Animal IDs. \
#    Examples with same animal ID are not duplicate examples. There exists animals that have come to the shelter more than once.\
#    We would like to keep cases with duplicate animal IDs, since information about returned animals can be useful.

# %%
returned_intakes = intakes[intakes.duplicated('Animal ID',keep='first')].sort_values(['Animal ID','DateTime'])
returned_intakes.head()
# Out:
#        Animal ID    Name    DateTime  \
# 84304    A006100   Scamp  2014-03-07
# 18662    A006100   Scamp  2017-12-07
# 113010   A245945  Boomer  2015-05-20
# 62644    A282897    Toby  2015-07-06
# 110013   A287017  Stitch  2014-12-12
#
#                                            Found Location      Intake Type  \
# 84304                        8700 Research in Austin (TX)    Public Assist
# 18662       Colony Creek And Hunters Trace in Austin (TX)            Stray
# 113010                   7403 Blessing Ave in Austin (TX)            Stray
# 62644                                         Austin (TX)  Owner Surrender
# 110013  Lazy Oaks /Westgate William Cannon in Austin (TX)            Stray
#
#        Intake Condition Animal Type Sex upon Intake  Age upon Intake  \
# 84304            Normal         Dog   Neutered Male                6
# 18662            Normal         Dog   Neutered Male               10
# 113010           Normal         Dog   Neutered Male               15
# 62644            Normal         Cat   Neutered Male               13
# 110013             Aged         Dog   Spayed Female               13
#
#                           Breed              Color  Year  Month
# 84304      Spinone Italiano Mix       Yellow/White  2014      3
# 18662      Spinone Italiano Mix       Yellow/White  2017     12
# 113010   Labrador Retriever Mix                Tan  2015      5
# 62644    Domestic Shorthair Mix  Black Smoke/White  2015      7
# 110013  Chihuahua Shorthair Mix        Black/White  2014     12

# %%
returned_outcomes = outcomes[outcomes.duplicated('Animal ID',keep='first')].sort_values(['Animal ID','DateTime'])
returned_outcomes.head()
# Out:
#        Animal ID    Name    DateTime     Outcome Type Outcome Subtype  \
# 107324   A006100   Scamp  2014-03-08  Return to Owner             NaN
# 94523    A006100   Scamp  2017-12-07  Return to Owner             NaN
# 84453    A245945  Boomer  2014-07-04  Return to Owner             NaN
# 106950   A282897    Toby  2015-07-11         Adoption             NaN
# 66245    A287017  Stitch  2015-08-16  Return to Owner             NaN
#
#        Animal Type Sex upon Outcome  Age upon Outcome  \
# 107324         Dog    Neutered Male                 6
# 94523          Dog    Neutered Male                10
# 84453          Dog    Neutered Male                14
# 106950         Cat    Neutered Male                13
# 66245          Dog    Spayed Female                14
#
#                           Breed              Color  Year  Month
# 107324     Spinone Italiano Mix       Yellow/White  2014      3
# 94523      Spinone Italiano Mix       Yellow/White  2017     12
# 84453    Labrador Retriever Mix                Tan  2014      7
# 106950   Domestic Shorthair Mix  Black Smoke/White  2015      7
# 66245   Chihuahua Shorthair Mix        Black/White  2015      8

# %%
print(intakes.shape[0])
print(outcomes.shape[0])
# Out:
# 124120
# 124491

# %%
# create a function that returns a column with new animal IDs (original animal ID + another digit that indicates returned animal)
def new_animalID(animalID_col):
    temp_dict = {}
    new_animalID_col = []
    for id in animalID_col:
        if id not in temp_dict.keys():
            temp_dict[id] = 1
        else:
            temp_dict[id] += 1
        new_animalID_col.append(id + '-'+ str(temp_dict[id]))
    return pd.Series(new_animalID_col, name='New_Animal_ID')

# %%
diff_col = []
for i in intakes.columns:
    if i not in outcomes.columns:
        diff_col.append(i)
print('diff_col: ' + str(diff_col))
same_col = []
for i in intakes.columns:
    if i in outcomes.columns:
        same_col.append(i)
print('same_col :' + str(same_col))
# Out:
# diff_col: ['Found Location', 'Intake Type', 'Intake Condition', 'Sex upon Intake', 'Age upon Intake']
# same_col :['Animal ID', 'Name', 'DateTime', 'Animal Type', 'Breed', 'Color', 'Year', 'Month']

# %%
intakes.rename(columns={'DateTime':'Intake_DateTime','Year':'Intake_Year','Month':'Intake_Month'},inplace=True)
intakes.head()
# Out:
#   Animal ID     Name Intake_DateTime                       Found Location  \
# 0   A786884   *Brock      2019-01-03  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle      2015-07-05     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster      2016-04-14   2818 Palomino Trail in Austin (TX)
# 3   A665644      NaN      2013-10-21                          Austin (TX)
# 4   A682524      Rio      2014-06-29        800 Grove Blvd in Austin (TX)
#
#   Intake Type Intake Condition Animal Type Sex upon Intake  Age upon Intake  \
# 0       Stray           Normal         Dog   Neutered Male                2
# 1       Stray           Normal         Dog   Spayed Female                8
# 2       Stray           Normal         Dog     Intact Male                0
# 3       Stray             Sick         Cat   Intact Female                0
# 4       Stray           Normal         Dog   Neutered Male                4
#
#                                    Breed        Color  Intake_Year  \
# 0                             Beagle Mix     Tricolor         2019
# 1               English Springer Spaniel  White/Liver         2015
# 2                            Basenji Mix  Sable/White         2016
# 3                 Domestic Shorthair Mix       Calico         2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2014
#
#    Intake_Month
# 0             1
# 1             7
# 2             4
# 3            10
# 4             6

# %%
outcomes.rename(columns={'DateTime':'Outcome_DateTime','Year':'Outcome_Year','Month':'Outcome_Month'},inplace=True)
outcomes.head()
# Out:
#   Animal ID   Name Outcome_DateTime Outcome Type Outcome Subtype Animal Type  \
# 0   A794011  Chunk       2019-05-08    Rto-Adopt             NaN         Cat
# 1   A776359  Gizmo       2018-07-18     Adoption             NaN         Dog
# 2   A821648    NaN       2020-08-16   Euthanasia             NaN       Other
# 3   A720371  Moose       2016-02-13     Adoption             NaN         Dog
# 4   A674754    NaN       2014-03-18     Transfer         Partner         Cat
#
#   Sex upon Outcome  Age upon Outcome                               Breed  \
# 0    Neutered Male                 2              Domestic Shorthair Mix
# 1    Neutered Male                 1             Chihuahua Shorthair Mix
# 2          Unknown                 1                             Raccoon
# 3    Neutered Male                 0  Anatol Shepherd/Labrador Retriever
# 4      Intact Male                 0              Domestic Shorthair Mix
#
#                Color  Outcome_Year  Outcome_Month
# 0  Brown Tabby/White          2019              5
# 1        White/Brown          2018              7
# 2               Gray          2020              8
# 3               Buff          2016              2
# 4       Orange Tabby          2014              3

# %%
# sort data by animal id and datetime to find out which case happened first among duplicate animal ids
intakes.sort_values(['Animal ID','Intake_DateTime'], ignore_index=True, inplace=True)
new_animalID_col = new_animalID(intakes['Animal ID'])
intakes['New_Animal_ID'] = new_animalID_col
intakes.head()
# Out:
#   Animal ID    Name Intake_DateTime  \
# 0   A006100   Scamp      2014-03-07
# 1   A006100   Scamp      2014-12-19
# 2   A006100   Scamp      2017-12-07
# 3   A047759    Oreo      2014-04-02
# 4   A134067  Bandit      2013-11-16
#
#                                   Found Location      Intake Type  \
# 0                   8700 Research in Austin (TX)    Public Assist
# 1              8700 Research Blvd in Austin (TX)    Public Assist
# 2  Colony Creek And Hunters Trace in Austin (TX)            Stray
# 3                                    Austin (TX)  Owner Surrender
# 4             12034 Research Blvd in Austin (TX)    Public Assist
#
#   Intake Condition Animal Type Sex upon Intake  Age upon Intake  \
# 0           Normal         Dog   Neutered Male                6
# 1           Normal         Dog   Neutered Male                7
# 2           Normal         Dog   Neutered Male               10
# 3           Normal         Dog   Neutered Male               10
# 4          Injured         Dog   Neutered Male               16
#
#                   Breed         Color  Intake_Year  Intake_Month New_Animal_ID
# 0  Spinone Italiano Mix  Yellow/White         2014             3     A006100-1
# 1  Spinone Italiano Mix  Yellow/White         2014            12     A006100-2
# 2  Spinone Italiano Mix  Yellow/White         2017            12     A006100-3
# 3             Dachshund      Tricolor         2014             4     A047759-1
# 4     Shetland Sheepdog   Brown/White         2013            11     A134067-1

# %%
outcomes.sort_values(['Animal ID','Outcome_DateTime'], ignore_index=True, inplace=True)
new_animalID_col = new_animalID(outcomes['Animal ID'])
outcomes['New_Animal_ID'] = new_animalID_col
outcomes.head()
# Out:
#   Animal ID    Name Outcome_DateTime     Outcome Type Outcome Subtype  \
# 0   A006100   Scamp       2014-03-08  Return to Owner             NaN
# 1   A006100   Scamp       2014-12-20  Return to Owner             NaN
# 2   A006100   Scamp       2017-12-07  Return to Owner             NaN
# 3   A047759    Oreo       2014-04-07         Transfer         Partner
# 4   A134067  Bandit       2013-11-16  Return to Owner             NaN
#
#   Animal Type Sex upon Outcome  Age upon Outcome                 Breed  \
# 0         Dog    Neutered Male                 6  Spinone Italiano Mix
# 1         Dog    Neutered Male                 7  Spinone Italiano Mix
# 2         Dog    Neutered Male                10  Spinone Italiano Mix
# 3         Dog    Neutered Male                10             Dachshund
# 4         Dog    Neutered Male                16     Shetland Sheepdog
#
#           Color  Outcome_Year  Outcome_Month New_Animal_ID
# 0  Yellow/White          2014              3     A006100-1
# 1  Yellow/White          2014             12     A006100-2
# 2  Yellow/White          2017             12     A006100-3
# 3      Tricolor          2014              4     A047759-1
# 4   Brown/White          2013             11     A134067-1

# %%
# some of columns in intakes and outcomes contain identical information
same_info_cols = ['Animal ID', 'Name', 'Animal Type', 'Breed', 'Color']
# merge intakes and outcomes without identical information
combined = intakes.merge(outcomes.drop(same_info_cols, axis=1), how='outer', on='New_Animal_ID')
combined.head()
# Out:
#   Animal ID    Name Intake_DateTime  \
# 0   A006100   Scamp      2014-03-07
# 1   A006100   Scamp      2014-12-19
# 2   A006100   Scamp      2017-12-07
# 3   A047759    Oreo      2014-04-02
# 4   A134067  Bandit      2013-11-16
#
#                                   Found Location      Intake Type  \
# 0                   8700 Research in Austin (TX)    Public Assist
# 1              8700 Research Blvd in Austin (TX)    Public Assist
# 2  Colony Creek And Hunters Trace in Austin (TX)            Stray
# 3                                    Austin (TX)  Owner Surrender
# 4             12034 Research Blvd in Austin (TX)    Public Assist
#
#   Intake Condition Animal Type Sex upon Intake  Age upon Intake  \
# 0           Normal         Dog   Neutered Male              6.0
# 1           Normal         Dog   Neutered Male              7.0
# 2           Normal         Dog   Neutered Male             10.0
# 3           Normal         Dog   Neutered Male             10.0
# 4          Injured         Dog   Neutered Male             16.0
#
#                   Breed  ... Intake_Year  Intake_Month  New_Animal_ID  \
# 0  Spinone Italiano Mix  ...      2014.0           3.0      A006100-1
# 1  Spinone Italiano Mix  ...      2014.0          12.0      A006100-2
# 2  Spinone Italiano Mix  ...      2017.0          12.0      A006100-3
# 3             Dachshund  ...      2014.0           4.0      A047759-1
# 4     Shetland Sheepdog  ...      2013.0          11.0      A134067-1
#
#   Outcome_DateTime     Outcome Type Outcome Subtype Sex upon Outcome  \
# 0       2014-03-08  Return to Owner             NaN    Neutered Male
# 1       2014-12-20  Return to Owner             NaN    Neutered Male
# 2       2017-12-07  Return to Owner             NaN    Neutered Male
# 3       2014-04-07         Transfer         Partner    Neutered Male
# 4       2013-11-16  Return to Owner             NaN    Neutered Male
#
#   Age upon Outcome  Outcome_Year  Outcome_Month
# 0              6.0        2014.0            3.0
# 1              7.0        2014.0           12.0
# 2             10.0        2017.0           12.0
# 3             10.0        2014.0            4.0
# 4             16.0        2013.0           11.0
#
# [5 rows x 21 columns]

# %%
print(returned_intakes.shape[0])
print(returned_outcomes.shape[0])
print(combined.shape[0])
# Out:
# 13194
# 13182
# 125045

# %%
combined.isnull().sum()
# Out:
# Animal ID             925
# Name                39976
# Intake_DateTime       925
# Found Location        925
# Intake Type           925
# Intake Condition      925
# Animal Type           925
# Sex upon Intake       926
# Age upon Intake       925
# Breed                 925
# Color                 925
# Intake_Year           925
# Intake_Month          925
# New_Animal_ID           0
# Outcome_DateTime      554
# Outcome Type          574
# Outcome Subtype     67737
# Sex upon Outcome      555
# Age upon Outcome      554
# Outcome_Year          554
# Outcome_Month         554
# dtype: int64

# %%
combined['Name'].unique
# Out:
# <bound method Series.unique of 0          Scamp
# 1          Scamp
# 2          Scamp
# 3           Oreo
# 4         Bandit
#            ...
# 125040       NaN
# 125041       NaN
# 125042       NaN
# 125043       NaN
# 125044       NaN
# Name: Name, Length: 125045, dtype: object>

# %%
import missingno as msno
msno.matrix(combined)
# Out:
# <AxesSubplot:>

# %%
same_info_cols
# Out:
# ['Animal ID', 'Name', 'Animal Type', 'Breed', 'Color']

# %%
combined.to_csv('Cleaned_Combined.csv')
